# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars.csv')

# %%
df.sample(5)
# Out:
#           brand  km_driven    fuel         owner  selling_price
# 7989    Hyundai      50000  Petrol   First Owner         470000
# 105    Mahindra      70000  Diesel  Second Owner         625000
# 7859      Lexus      20000  Petrol   First Owner        5150000
# 3707  Chevrolet      60000  Petrol   First Owner         180000
# 1150      Honda       7032  Petrol   First Owner         779000

# %%
df['fuel'].value_counts()
# Out:
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: fuel, dtype: int64

# %% [markdown]
# # one hot encoding

# %%
pd.get_dummies(df,columns =['fuel','owner']).head()
# Out:
#      brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0   Maruti     145500         450000         0            1         0
# 1    Skoda     120000         370000         0            1         0
# 2    Honda     140000         158000         0            0         0
# 3  Hyundai     127000         225000         0            1         0
# 4   Maruti     120000         130000         0            0         0
#
#    fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# 0            0                  1                           0
# 1            0                  0                           0
# 2            1                  0                           0
# 3            0                  1                           0
# 4            1                  1                           0
#
#    owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# 0                   0                     0                  0
# 1                   1                     0                  0
# 2                   0                     0                  1
# 3                   0                     0                  0
# 4                   0                     0                  0

# %% [markdown]
# # k-1 encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                              0                   0                     0
# 1                              0                   1                     0
# 2                              0                   0                     0
# 3                              0                   0                     0
# 4                              0                   0                     0
# ...                          ...                 ...                   ...
# 8123                           0                   0                     0
# 8124                           1                   0                     0
# 8125                           0                   0                     0
# 8126                           0                   0                     0
# 8127                           0                   0                     0
#
#       owner_Third Owner
# 0                     0
# 1                     0
# 2                     1
# 3                     0
# 4                     0
# ...                 ...
# 8123                  0
# 8124                  0
# 8125                  0
# 8126                  0
# 8127                  0
#
# [8128 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first',sparse=False,dtype=np.int32)

# %%
X_train_new = ohe.fit_transform(X_train[['fuel','owner']])
# Out:
# C:\Users\expert\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_test_new = ohe.transform(X_test[['fuel','owner']])

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new)).shape
# Out:
# (6502, 9)

# %% [markdown]
# # OneHotEncoding with Top Categories

# %%
counts = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

# %%
repl = counts[counts<=threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl,'uncommon')).sample(5)
# Out:
#       BMW  Chevrolet  Ford  Honda  Hyundai  Mahindra  Maruti  Renault  Skoda  \
# 6732    0          0     0      0        0         0       1        0      0
# 7751    0          0     0      0        1         0       0        0      0
# 724     0          0     0      0        0         1       0        0      0
# 6192    0          0     0      0        0         0       1        0      0
# 3226    0          0     0      0        0         0       1        0      0
#
#       Tata  Toyota  Volkswagen  uncommon
# 6732     0       0           0         0
# 7751     0       0           0         0
# 724      0       0           0         0
# 6192     0       0           0         0
# 3226     0       0           0         0
